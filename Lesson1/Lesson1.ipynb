# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.dataset import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.sgdr import *
from fastai.plots import *

# %%
path = "/home/mahathi/Desktop/Workspace/fast_ai/data/imagenet/"

# %%
sz=224
bs=28

# %%
jpg_img = plt.imread(f'/home/mahathi/Desktop/Workspace/fast_ai/data/imagenet/train/dogs/n02087394_18618.JPEG')

# %%
plt.imshow(jpg_img)

# %%
arch=resnet34

# %%
resized_data = ImageClassifierData.from_paths(path, tfms=tfms_from_model(arch, sz))

# %%
learn = ConvLearner.pretrained(arch, resized_data, precompute=True)

# %%
lrf = learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch:   0, train_loss: 0.363402, val_loss: 30.554064, accuracy: 0.968750

# %%
learn.sched.plot()

# %%
learn.fit(0.1, 3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch:   0, train_loss: 0.045826, val_loss: 0.000010, accuracy: 1.000000
# epoch:   1, train_loss: 0.015951, val_loss: 0.000006, accuracy: 1.000000
# epoch:   2, train_loss: 0.008880, val_loss: 0.000001, accuracy: 1.000000
